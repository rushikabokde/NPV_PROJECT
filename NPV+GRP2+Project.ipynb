# %% [markdown]
# # Mini Project - Python
# Asset Management Company Dataset

# %% [markdown]
# ### 1. Reading the Rounds2, companies.txt files.

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = "ignore")

# %%
#1A ANSWER: Read Text Files with Pandas using read_csv()
# read text file into pandas DataFrame
companies = pd.read_csv("DATASET/companies.txt",sep = "\t")

# %%
#1A ANSWER: Read csv Files with Pandas using read_csv()
# read text file into pandas DataFrame
rounds = pd.read_csv("DATASET/rounds2.csv",encoding = 'iso-8859-1')

# %%
# display DataFrame
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
# display DataFrame
rounds.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %% [markdown]
# ### 2. How many unique companies are present in rounds2?

# %%
print("The number of unique companies present in rounds2 dataset is:",len(rounds["company_permalink"].unique()))
# Out:
# The number of unique companies present in rounds2 dataset is: 90247

# %% [markdown]
# ### 3. How many unique companies are present in the companies file?

# %%
print("The number of unique companies present in companies dataset is:",len(companies["permalink"].unique()))
# Out:
# The number of unique companies present in companies dataset is: 66368

# %% [markdown]
# ### 4.Write the code to convert companies[‘permalink’] and Round2[‘company_permalink’] columns to uppercase.

# %%
#Converting column to upper class using upper func
companies["permalink"] = companies["permalink"].str.upper()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# 2  /ORGANIZATION/-THE-ONE-OF-THEM-INC-  (THE) ONE of THEM,Inc.
# 3                /ORGANIZATION/0-6-COM                 0-6.com
# 4       /ORGANIZATION/004-TECHNOLOGIES        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
#Converting column to upper class using upper func
rounds["company_permalink"] = rounds["company_permalink"].str.upper()
rounds.head()
# Out:
#                      company_permalink  \
# 0                  /ORGANIZATION/-FAME
# 1               /ORGANIZATION/-QOUNTER
# 2               /ORGANIZATION/-QOUNTER
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /ORGANIZATION/0-6-COM
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %% [markdown]
# ### 5. Are there any companies in the rounds2 file which are not present in companies.txt ?

# %%
#difference between len(rounds["company_permalink"].unique() and len(companies["permalink"].unique())
#Unique records recored in A & B 
A = pd.DataFrame(rounds["company_permalink"].unique())
B = pd.DataFrame(companies["permalink"].unique())

# %%
len(set(rounds['company_permalink'].unique()).difference(set(companies['permalink'].unique())))
# Out:
# 29

# %%
print("companies in the rounds2 file which are not present in companies.txtset are:","\n","\n"
      ,set(rounds['company_permalink'].unique()).difference(set(companies['permalink'].unique())))
# Out:
# companies in the rounds2 file which are not present in companies.txtset are:
#
# ...

# %% [markdown]
# ### 6. Merge the two data frames so that all variables (columns) in the company's frame are added to the rounds2 data frame. Name the merged frame master_dataframe. How many observations are present in master_frame ?

# %%
master_dataframe = pd.merge(rounds,companies, how = "left", left_on="company_permalink", right_on="permalink")
master_dataframe.head()
# Out:
#                      company_permalink  \
# 0                  /ORGANIZATION/-FAME
# 1               /ORGANIZATION/-QOUNTER
# 2               /ORGANIZATION/-QOUNTER
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /ORGANIZATION/0-6-COM
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd  \
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %% [markdown]
# ### 7. Write the code to drop the redundant column ‘'company_permalink' from the master_dataframe.

# %%
master_dataframe = master_dataframe.drop(["company_permalink"],axis = 1)
master_dataframe.head()
# Out:
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd  \
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0
#
#                              permalink                    name  \
# 0                  /ORGANIZATION/-FAME                   #fame
# 1               /ORGANIZATION/-QOUNTER                :Qounter
# ...

# %% [markdown]
# ### 8. Write the code to find the percentage missing value (column-wise) in master_dataframe. Drop unnecessary columns.

# %%
master_dataframe.info()
q8=master_dataframe.isnull().sum(axis=0)*100/len(master_dataframe)
print(round(q8,2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   funding_round_code       31140 non-null   object
#  3   funded_at                114949 non-null  object
#  4   raised_amount_usd        94959 non-null   float64
#  5   permalink                114917 non-null  object
#  6   name                     114916 non-null  object
#  7   homepage_url             108788 non-null  object
#  8   category_list            111518 non-null  object
#  9   status                   114917 non-null  object
#  10  country_code             106263 non-null  object
#  11  state_code               103996 non-null  object
#  12  region                   104774 non-null  object
# ...

# %%
master_dataframe
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# ...

# %%
master_dataframe = master_dataframe.drop(["funded_at"],axis = 1)

# %%
master_dataframe = master_dataframe.drop(["funding_round_code"],axis = 1)

# %%
print("As we have observed the missing values of columns ['funded_at','funding_round_code'] are more than 15% which is more as compared to other column missing rate so we have decided to drop these two columns. Since 'raised_amount_usd' is useful in next questions so we have avoided dropping the column")
master_dataframe.info()
# Out:
# As we have observed the missing values of columns ['funded_at','funding_round_code'] are more than 15% which is more as compared to other column missing rate so we have decided to drop these two columns. Since 'raised_amount_usd' is useful in next questions so we have avoided dropping the column
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  object
#  7   status                   114917 non-null  object
# ...

# %% [markdown]
# ### 9. Create a pivot table to compare the mean and median values for ‘raised_amount_usd’ and ‘funding_round_type’ across different funding round categories..

# %%
pd.pivot_table(master_dataframe,values = 'raised_amount_usd', index = 'funding_round_type', aggfunc = {np.mean,np.median})
# Out:
#                                mean      median
# funding_round_type
# angel                  9.586945e+05    400000.0
# convertible_note       1.453439e+06    272000.0
# debt_financing         1.704353e+07   1100000.0
# equity_crowdfunding    5.383682e+05    100000.0
# grant                  4.300576e+06    201684.0
# non_equity_assistance  4.112031e+05     60000.0
# post_ipo_debt          1.687046e+08  19950000.0
# post_ipo_equity        8.218249e+07  12262852.5
# private_equity         7.330859e+07  20000000.0
# product_crowdfunding   1.363131e+06    183915.0
# secondary_market       7.964963e+07  32600000.0
# seed                   7.198180e+05    275000.0
# undisclosed            1.924237e+07   1018680.0
# venture                1.174895e+07   5000000.0

# %% [markdown]
# ### 10. Filter the master_dataframe on ‘raised_amount_usd’ such as ‘raised_amount_usd’ lie between 4 Millions to 15 Millions.

# %%
master_dataframe[(master_dataframe["raised_amount_usd"]>4000000) & (master_dataframe["raised_amount_usd"]<15000000)]
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 12      /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e            venture
# 21      /funding-round/11c228f58831bc7ed337ef69ecc560c2     private_equity
# 22      /funding-round/b952cbaf401f310927430c97b68162ea            venture
# 46      /funding-round/645b4cd895450b8e0268027cd7813047            venture
# ...                                                 ...                ...
# 114921  /funding-round/85443f5438bfd50104b9591eabc95c94              grant
# 114922  /funding-round/b4fce7f8a13267353d57db09099800e8            venture
# 114930  /funding-round/c05aab2155e390066d51c6852ff61464              grant
# 114931  /funding-round/e949f077c943db197f20e43c2eb8d0e6            venture
# 114936  /funding-round/7ea37c0ff4132b084832039a9380d34e            venture
#
# ...

# %% [markdown]
# ### 11.Identify the top 9 countries in terms of highest investment in ‘venture’ fund type.

# %%
V = master_dataframe[master_dataframe.funding_round_type=="venture"]
V
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 5       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# ...                                                 ...                ...
# 114934  /funding-round/7a0fa791c96c9c447ee54662395beab9            venture
# 114936  /funding-round/7ea37c0ff4132b084832039a9380d34e            venture
# 114937  /funding-round/0c43e717298296d2fb334fb236300f6e            venture
# 114941  /funding-round/171693e1e07e0230defd8fddb6de4515            venture
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
#
# ...

# %%
country = V.groupby('country_code')['raised_amount_usd'].sum().sort_values(ascending=False)

# %%
Top = country[:9]

# %%
Top
# Out:
# country_code
# USA    4.225108e+11
# CHN    3.983542e+10
# GBR    2.024563e+10
# IND    1.439186e+10
# CAN    9.583332e+09
# FRA    7.259537e+09
# ISR    6.907515e+09
# DEU    6.346960e+09
# JPN    3.363677e+09
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# ### 12. Create the ‘main_category’ column by extracting the main sector using the column ‘category_list’.
# Hint - Use the Lambda function or string function.

# %%
master_dataframe.category_list
# Out:
# 0                                                     Media
# 1         Application Platforms|Real Time|Social Network...
# 2         Application Platforms|Real Time|Social Network...
# 3                                         Apps|Games|Mobile
# 4                                               Curated Web
#                                 ...
# 114944          Advertising|Mobile|Web Development|Wireless
# 114945          Advertising|Mobile|Web Development|Wireless
# 114946                                                  NaN
# 114947                                                  NaN
# 114948                   Consumer Goods|E-Commerce|Internet
# Name: category_list, Length: 114949, dtype: object

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  object
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# dtypes: float64(1), object(12)
# ...

# %%
master_dataframe.category_list = master_dataframe.category_list.astype("category")

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  category
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# ...

# %%
master_dataframe.category_list
# Out:
# 0                                                     Media
# 1         Application Platforms|Real Time|Social Network...
# 2         Application Platforms|Real Time|Social Network...
# 3                                         Apps|Games|Mobile
# 4                                               Curated Web
#                                 ...
# 114944          Advertising|Mobile|Web Development|Wireless
# 114945          Advertising|Mobile|Web Development|Wireless
# 114946                                                  NaN
# 114947                                                  NaN
# 114948                   Consumer Goods|E-Commerce|Internet
# Name: category_list, Length: 114949, dtype: category
# Categories (27289, object): ['3D', '3D Printing', '3D Printing|3D Technology', '3D Printing|3D Technology|Android|Artificial ..., ..., 'mHealth', 'mHealth|Mobile', 'mHealth|Software', 'mHealth|Software|Therapeutics']

# %%
master_dataframe.loc[:, 'main_category'] = master_dataframe['category_list'].apply(lambda x: x.split("|")[0])
master_dataframe[['category_list','main_category']]
# Out:
#                                             category_list  \
# 0                                                   Media
# 1       Application Platforms|Real Time|Social Network...
# 2       Application Platforms|Real Time|Social Network...
# 3                                       Apps|Games|Mobile
# 4                                             Curated Web
# ...                                                   ...
# 114944        Advertising|Mobile|Web Development|Wireless
# 114945        Advertising|Mobile|Web Development|Wireless
# 114946                                                NaN
# 114947                                                NaN
# 114948                 Consumer Goods|E-Commerce|Internet
#
#                 main_category
# 0                       Media
# 1       Application Platforms
# 2       Application Platforms
# 3                        Apps
# 4                 Curated Web
# ...                       ...
# 114944            Advertising
# ...

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  category
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# ...

# %% [markdown]
# ### 13. Using the user defined function convert the ‘rasied_amount_used’ column into a categorical column as follow-
# a) If the amount is less than 5 Millions then recode as TypeA.
# b) If the amount is greater than 5 Millions and less than 7 Millions then recode as TypeB. c) If the amount is greater than 7 Millions then recode as TypeC.

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  category
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# ...

# %%
def converter(x):
    if x < 5000000.0:
        return "TypeA"
    elif (x > 5000000.0) & (x < 7000000.0):
        return "TypeB"
    else:
        return "TypeC"

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        94959 non-null   float64
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  category
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# ...

# %%
master_dataframe["raised_amount_usd"] = master_dataframe["raised_amount_usd"].apply(converter)
master_dataframe["raised_amount_usd"] = master_dataframe["raised_amount_usd"].astype('category')

# %%
master_dataframe
# Out:
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
# ...

# %%
master_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   funding_round_permalink  114949 non-null  object
#  1   funding_round_type       114949 non-null  object
#  2   raised_amount_usd        114949 non-null  category
#  3   permalink                114917 non-null  object
#  4   name                     114916 non-null  object
#  5   homepage_url             108788 non-null  object
#  6   category_list            111518 non-null  category
#  7   status                   114917 non-null  object
#  8   country_code             106263 non-null  object
#  9   state_code               103996 non-null  object
#  10  region                   104774 non-null  object
#  11  city                     104777 non-null  object
#  12  founded_at               94407 non-null   object
# ...
